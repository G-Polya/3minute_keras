# %%
from keras import layers,models
from keras import datasets
from sklearn import preprocessing
import matplotlib.pyplot as plt
from skeras import plot_loss

# %%
class ANN(models.Model):
    def __init__(self, Nin, Nh, Nout):
        hidden = layers.Dense(Nh)
        output = layers.Dense(Nout)
        relu = layers.Activation('relu')
        
        x = layers.Input(shape=(Nin,))
        h = relu(hidden(x))
        y = output(h)
        
        super().__init__(x,y)
        self.compile(loss='mse', optimizer='sgd')

# %%
def Data_func():
    (X_train, y_train), (X_test, y_test) = datasets.boston_housing.load_data()
    scaler = preprocessing.MinMaxScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    return (X_train,y_train), (X_test, y_test)

# %%
Nin = 13
Nh = 5
Nout = 1
model = ANN(Nin, Nh, Nout)
(X_train, y_train), (X_test,y_test) = Data_func()
history = model.fit(X_train,y_train, epochs=100, batch_size=100,validation_split=0.2,verbose=2)
performance_test = model.evaluate(X_test,y_test, batch_size=100)
print('\nTest Loss -> {:.2f}'.format(performance_test))

plot_loss(history)
plt.show()
# Out:
# Train on 323 samples, validate on 81 samples
# Epoch 1/100
#  - 0s - loss: 517.4884 - val_loss: 224.3083
# Epoch 2/100
#  - 0s - loss: 116.9150 - val_loss: 84.7352
# Epoch 3/100
#  - 0s - loss: 78.3049 - val_loss: 74.7980
# Epoch 4/100
#  - 0s - loss: 68.5533 - val_loss: 74.4060
# Epoch 5/100
#  - 0s - loss: 65.4752 - val_loss: 61.8472
# Epoch 6/100
#  - 0s - loss: 63.7296 - val_loss: 63.8294
# Epoch 7/100
#  - 0s - loss: 55.6457 - val_loss: 108.7461
# Epoch 8/100
#  - 0s - loss: 74.3348 - val_loss: 58.4163
# Epoch 9/100
#  - 0s - loss: 49.7567 - val_loss: 64.1005
# Epoch 10/100
#  - 0s - loss: 54.2879 - val_loss: 46.4408
# Epoch 11/100
#  - 0s - loss: 44.9623 - val_loss: 48.6260
# Epoch 12/100
#  - 0s - loss: 42.8660 - val_loss: 51.6366
# Epoch 13/100
#  - 0s - loss: 51.4358 - val_loss: 47.0947
# Epoch 14/100
#  - 0s - loss: 43.1595 - val_loss: 46.2038
# Epoch 15/100
#  - 0s - loss: 37.3968 - val_loss: 74.2133
# Epoch 16/100
#  - 0s - loss: 47.8573 - val_loss: 36.0305
# Epoch 17/100
#  - 0s - loss: 34.1817 - val_loss: 34.3700
# Epoch 18/100
#  - 0s - loss: 38.6031 - val_loss: 35.9825
# Epoch 19/100
#  - 0s - loss: 35.3248 - val_loss: 34.0892
# Epoch 20/100
#  - 0s - loss: 32.2487 - val_loss: 31.5633
# Epoch 21/100
#  - 0s - loss: 30.5925 - val_loss: 31.6626
# Epoch 22/100
#  - 0s - loss: 31.8833 - val_loss: 30.9321
# Epoch 23/100
#  - 0s - loss: 29.9515 - val_loss: 30.3592
# Epoch 24/100
#  - 0s - loss: 27.8060 - val_loss: 32.5030
# Epoch 25/100
#  - 0s - loss: 31.3237 - val_loss: 27.5171
# Epoch 26/100
#  - 0s - loss: 27.0355 - val_loss: 30.0855
# Epoch 27/100
#  - 0s - loss: 26.0764 - val_loss: 26.0224
# Epoch 28/100
#  - 0s - loss: 28.6439 - val_loss: 48.4129
# Epoch 29/100
#  - 0s - loss: 54.4800 - val_loss: 45.8483
# Epoch 30/100
#  - 0s - loss: 48.2598 - val_loss: 25.7917
# Epoch 31/100
#  - 0s - loss: 29.4988 - val_loss: 24.1167
# Epoch 32/100
#  - 0s - loss: 24.4923 - val_loss: 25.4100
# Epoch 33/100
#  - 0s - loss: 25.8179 - val_loss: 29.5213
# Epoch 34/100
#  - 0s - loss: 38.6655 - val_loss: 44.2836
# Epoch 35/100
#  - 0s - loss: 32.1086 - val_loss: 64.8640
# Epoch 36/100
#  - 0s - loss: 49.7674 - val_loss: 36.1796
# Epoch 37/100
#  - 0s - loss: 34.5930 - val_loss: 28.2732
# Epoch 38/100
#  - 0s - loss: 27.5196 - val_loss: 22.2903
# Epoch 39/100
#  - 0s - loss: 24.9689 - val_loss: 31.2147
# Epoch 40/100
#  - 0s - loss: 27.6299 - val_loss: 81.4721
# Epoch 41/100
#  - 0s - loss: 46.5311 - val_loss: 60.3696
# Epoch 42/100
#  - 0s - loss: 37.0542 - val_loss: 42.7583
# Epoch 43/100
#  - 0s - loss: 41.7789 - val_loss: 26.8885
# Epoch 44/100
#  - 0s - loss: 24.0947 - val_loss: 23.5206
# Epoch 45/100
#  - 0s - loss: 22.3291 - val_loss: 20.8996
# Epoch 46/100
#  - 0s - loss: 21.7461 - val_loss: 25.3048
# Epoch 47/100
#  - 0s - loss: 22.6510 - val_loss: 21.1176
# Epoch 48/100
#  - 0s - loss: 22.5242 - val_loss: 35.8469
# Epoch 49/100
#  - 0s - loss: 39.8264 - val_loss: 45.9701
# Epoch 50/100
#  - 0s - loss: 31.2011 - val_loss: 33.6666
# Epoch 51/100
#  - 0s - loss: 37.2401 - val_loss: 42.1905
# Epoch 52/100
#  - 0s - loss: 43.1011 - val_loss: 23.4535
# Epoch 53/100
#  - 0s - loss: 22.0346 - val_loss: 24.1003
# Epoch 54/100
#  - 0s - loss: 25.1155 - val_loss: 19.7646
# Epoch 55/100
#  - 0s - loss: 21.6255 - val_loss: 19.1520
# Epoch 56/100
#  - 0s - loss: 19.9375 - val_loss: 18.9767
# Epoch 57/100
#  - 0s - loss: 20.2421 - val_loss: 18.9680
# Epoch 58/100
#  - 0s - loss: 28.8929 - val_loss: 43.5410
# Epoch 59/100
#  - 0s - loss: 54.0853 - val_loss: 27.9874
# Epoch 60/100
#  - 0s - loss: 36.0855 - val_loss: 19.3613
# Epoch 61/100
#  - 0s - loss: 20.2338 - val_loss: 18.9903
# Epoch 62/100
#  - 0s - loss: 20.2325 - val_loss: 19.2745
# Epoch 63/100
#  - 0s - loss: 19.9514 - val_loss: 20.9858
# Epoch 64/100
#  - 0s - loss: 19.9745 - val_loss: 28.6336
# Epoch 65/100
#  - 0s - loss: 25.6797 - val_loss: 32.0060
# Epoch 66/100
#  - 0s - loss: 33.2821 - val_loss: 18.0924
# Epoch 67/100
#  - 0s - loss: 19.3671 - val_loss: 19.6716
# Epoch 68/100
#  - 0s - loss: 19.6528 - val_loss: 21.9170
# Epoch 69/100
#  - 0s - loss: 26.9343 - val_loss: 80.1458
# Epoch 70/100
#  - 0s - loss: 75.0006 - val_loss: 54.1675
# Epoch 71/100
#  - 0s - loss: 42.8164 - val_loss: 25.6850
# Epoch 72/100
#  - 0s - loss: 20.8484 - val_loss: 22.0028
# Epoch 73/100
#  - 0s - loss: 22.3131 - val_loss: 41.6266
# Epoch 74/100
#  - 0s - loss: 25.9578 - val_loss: 17.6049
# Epoch 75/100
#  - 0s - loss: 20.3366 - val_loss: 48.1472
# Epoch 76/100
#  - 0s - loss: 41.1653 - val_loss: 17.0585
# Epoch 77/100
#  - 0s - loss: 21.4240 - val_loss: 29.5627
# Epoch 78/100
#  - 0s - loss: 26.6781 - val_loss: 19.1149
# Epoch 79/100
#  - 0s - loss: 23.1185 - val_loss: 32.5630
# Epoch 80/100
#  - 0s - loss: 26.5156 - val_loss: 17.2691
# Epoch 81/100
#  - 0s - loss: 18.5396 - val_loss: 17.2665
# Epoch 82/100
#  - 0s - loss: 18.9974 - val_loss: 27.2516
# Epoch 83/100
#  - 0s - loss: 26.2434 - val_loss: 22.1769
# Epoch 84/100
#  - 0s - loss: 19.2574 - val_loss: 16.3324
# Epoch 85/100
#  - 0s - loss: 19.1693 - val_loss: 17.0289
# Epoch 86/100
#  - 0s - loss: 21.5691 - val_loss: 16.3497
# Epoch 87/100
#  - 0s - loss: 17.4606 - val_loss: 16.1455
# Epoch 88/100
#  - 0s - loss: 17.6641 - val_loss: 16.7996
# Epoch 89/100
#  - 0s - loss: 17.7545 - val_loss: 16.0790
# Epoch 90/100
#  - 0s - loss: 17.4833 - val_loss: 16.8912
# Epoch 91/100
#  - 0s - loss: 17.4510 - val_loss: 15.9082
# Epoch 92/100
#  - 0s - loss: 17.2089 - val_loss: 16.2010
# Epoch 93/100
#  - 0s - loss: 17.1114 - val_loss: 19.5225
# Epoch 94/100
#  - 0s - loss: 19.9636 - val_loss: 16.9351
# Epoch 95/100
#  - 0s - loss: 17.3682 - val_loss: 25.3470
# Epoch 96/100
#  - 0s - loss: 26.0777 - val_loss: 23.2870
# Epoch 97/100
#  - 0s - loss: 23.8379 - val_loss: 24.1388
# Epoch 98/100
#  - 0s - loss: 19.4504 - val_loss: 15.7949
# Epoch 99/100
#  - 0s - loss: 16.9664 - val_loss: 15.7376
# Epoch 100/100
#  - 0s - loss: 18.4133 - val_loss: 15.3323
# 102/102 [==============================] - 0s 20us/step
#
# Test Loss -> 25.95
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-b28a51090226> in <module>
#       8 print('\nTest Loss -> {:.2f}'.format(performance_test))
#       9
# ---> 10 plot_loss(history)
#      11 plt.show()
#
# ~\Documents\3minute_keras\skeras.py in plot_loss(history)
#       1 # history를 표현하는 함수
#       2 def plot_loss(history):
# ----> 3     plt.plot(history.history['loss'])
#       4     plt.plot(history.history['val_loss'])
#       5     plt.title('Model Loss')
#
# NameError: name 'plt' is not defined
